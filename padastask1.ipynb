# %%
import pandas as pd

df= pd.read_csv("C:\\Users\\varun\\Downloads\\archive (4).zip")

df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df.head(500)
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10168               36      96.66                1  3479.76
# ..           ...              ...        ...              ...      ...
# 495        10332               27      89.89               16  2427.03
# 496        10347               21      58.95                7  1237.95
# 497        10356               22      72.41                6  1593.02
# 498        10369               32      98.63                7  3156.16
# 499        10391               42     119.00                3  4998.00
#
#       ORDERDATE  DAYS_SINCE_LASTORDER   STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
df.tail(100)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2647        10167               28     107.25               14  3003.00
# 2648        10177               24     105.27                5  2526.48
# 2649        10185               22      79.45                5  1747.90
# 2650        10197               35      93.35               11  3267.25
# 2651        10208               33      85.41                5  2818.53
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER     STATUS PRODUCTLINE  MSRP  \
# ...

# %%
df.shape
# Out:
# (2747, 20)

# %%
df.max
# Out:
# <bound method DataFrame.max of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df.idxmax
# Out:
# <bound method DataFrame.idxmax of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
len(df.index)
# Out:
# 2747

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.__len__
# Out:
# <bound method DataFrame.__len__ of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
import pandas as pd

df= pd.read_csv("C:\\Users\\varun\\Downloads\\archive (4).zip")

df["ORDERNUMBER"]
# Out:
# 0       10107
# 1       10121
# 2       10134
# 3       10145
# 4       10168
#         ...
# 2742    10350
# 2743    10373
# 2744    10386
# 2745    10397
# 2746    10414
# Name: ORDERNUMBER, Length: 2747, dtype: int64

# %%
df["QUANTITYORDERED"]
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       36
#         ..
# 2742    20
# 2743    29
# 2744    43
# 2745    34
# 2746    47
# Name: QUANTITYORDERED, Length: 2747, dtype: int64

# %%
import pandas as pd

df= pd.read_csv("C:\\Users\\varun\\Downloads\\archive (4).zip")

len(df["ORDERNUMBER"])
# Out:
# 2747

# %%
df["CITY"]
# Out:
# 0              NYC
# 1            Reims
# 2            Paris
# 3         Pasadena
# 4       Burlingame
#            ...
# 2742        Madrid
# 2743          Oulu
# 2744        Madrid
# 2745      Toulouse
# 2746        Boston
# Name: CITY, Length: 2747, dtype: object

# %%
df["SALES"].head(100)
# Out:
# 0      2871.00
# 1      2765.90
# 2      3884.34
# 3      3746.70
# 4      3479.76
#         ...
# 95     1822.17
# 96    11886.60
# 97     9218.16
# 98     7208.00
# 99     5004.80
# Name: SALES, Length: 100, dtype: float64

# %%
df["DAYS_SINCE_LASTORDER"].head(100)
# Out:
# 0     828
# 1     757
# 2     703
# 3     649
# 4     586
#      ...
# 95    185
# 96    150
# 97    116
# 98    939
# 99    864
# Name: DAYS_SINCE_LASTORDER, Length: 100, dtype: int64

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df["ORDERDATE"]
# Out:
# 0       24/02/2018
# 1       07/05/2018
# 2       01/07/2018
# 3       25/08/2018
# 4       28/10/2018
#            ...
# 2742    02/12/2019
# 2743    31/01/2020
# 2744    01/03/2020
# 2745    28/03/2020
# 2746    06/05/2020
# Name: ORDERDATE, Length: 2747, dtype: object

# %%
df["STATUS"].dtype
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df["POSTALCODE"]
# Out:
# 0       10022
# 1       51100
# 2       75508
# 3       90003
# 4       94217
#         ...
# 2742    28034
# 2743    90110
# 2744    28034
# 2745    31000
# 2746    51003
# Name: POSTALCODE, Length: 2747, dtype: object

# %%
df["MSRP"].head(10)
# Out:
# 0    95
# 1    95
# 2    95
# 3    95
# 4    95
# 5    95
# 6    95
# 7    95
# 8    95
# 9    95
# Name: MSRP, dtype: int64

# %%
df["QUANTITYORDERED"].dtype
# Out:
# dtype('int64')
